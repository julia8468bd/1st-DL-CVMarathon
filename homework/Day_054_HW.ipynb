# %% [markdown]
# # 作業
# * 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)

# %% [markdown]
# 非監督式學習主要是想找出，資料局部或全局相互的關係，較無特定的測量標準，多數無法使用評價函數。
#
# 在有目標值的情況下，可以分群後觀察其與真實label之間的關係；沒有目標值的話，可以做組內的相似度分析(統計學)，來觀察分群效果的好壞。
