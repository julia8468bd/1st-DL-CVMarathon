# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
lr = 0.1 # Learning rate
precision = 0.000001 #This tells us when to stop the algorithm
previous_step_size = 1 #
max_iters = 10000 # maximum number of iterations
iters = 0 #iteration counter
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
iters_history = [iters]
x_history = [cur_x]

while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x
    cur_x = cur_x - lr * df(prev_x) #Gradient descent
    previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
    iters = iters+1 #iteration count
    print("Iteration",iters,"\nX value is",cur_x) #Print iterations
    # Store parameters for plotting
    iters_history.append(iters)
    x_history.append(cur_x)
    print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
# Out:
# Iteration 1
# X value is 1.4
# the learning rate is 0.1
# Iteration 1
# X value is 1.4
# Iteration 2
# X value is 0.11999999999999966
# the learning rate is 0.1
# Iteration 2
# X value is 0.11999999999999966
# Iteration 3
# X value is -0.9040000000000001
# the learning rate is 0.1
# Iteration 3
# X value is -0.9040000000000001
# Iteration 4
# X value is -1.7232000000000003
# the learning rate is 0.1
# Iteration 4
# X value is -1.7232000000000003
# Iteration 5
# X value is -2.3785600000000002
# the learning rate is 0.1
# Iteration 5
# X value is -2.3785600000000002
# Iteration 6
# X value is -2.902848
# the learning rate is 0.1
# Iteration 6
# X value is -2.902848
# Iteration 7
# X value is -3.3222784
# the learning rate is 0.1
# Iteration 7
# X value is -3.3222784
# Iteration 8
# X value is -3.65782272
# the learning rate is 0.1
# Iteration 8
# X value is -3.65782272
# Iteration 9
# X value is -3.926258176
# the learning rate is 0.1
# Iteration 9
# X value is -3.926258176
# ...

# %%
print("Totally iteations: ", iters)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  66
# The local minimum occurs at -4.999996786123911

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.title('lr=0.1')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()

# %%
cur_x2 = 3 # The algorithm starts at x=3
lr2 = 0.0001 # Learning rate
precision2 = 0.000001 #This tells us when to stop the algorithm
previous_step_size2 = 1 #
max_iters2 = 10000 # maximum number of iterations
iters2 = 0 #iteration counter
df2 = lambda x: 2*(x+5) #Gradient of our function

# %%
iters_history2 = [iters2]
x_history2 = [cur_x2]

while previous_step_size2 > precision2 and iters2 < max_iters2:
    prev_x2 = cur_x2 #Store current x value in prev_x
    cur_x2 = cur_x2 - lr2 * df(prev_x) #Gradient descent
    previous_step_size = abs(cur_x2 - prev_x2) # 取較大的值, Change in x
    iters2 = iters2+1 #iteration count
    print("Iteration",iters2,"\nX value is",cur_x2) #Print iterations
    # Store parameters for plotting
    iters_history2.append(iters2)
    x_history2.append(cur_x2)
    print("the learning rate is",lr2, "\nIteration",iters2,"\nX value is",cur_x2) #Print iterations
# Out:
# Iteration 1
# X value is 2.999999999196531
# the learning rate is 0.0001
# Iteration 1
# X value is 2.999999999196531
# Iteration 2
# X value is 2.9999999983930623
# the learning rate is 0.0001
# Iteration 2
# X value is 2.9999999983930623
# Iteration 3
# X value is 2.9999999975895935
# the learning rate is 0.0001
# Iteration 3
# X value is 2.9999999975895935
# Iteration 4
# X value is 2.9999999967861246
# the learning rate is 0.0001
# Iteration 4
# X value is 2.9999999967861246
# Iteration 5
# X value is 2.9999999959826558
# the learning rate is 0.0001
# Iteration 5
# X value is 2.9999999959826558
# Iteration 6
# X value is 2.999999995179187
# the learning rate is 0.0001
# Iteration 6
# X value is 2.999999995179187
# Iteration 7
# X value is 2.999999994375718
# the learning rate is 0.0001
# Iteration 7
# X value is 2.999999994375718
# Iteration 8
# X value is 2.9999999935722492
# the learning rate is 0.0001
# Iteration 8
# X value is 2.9999999935722492
# Iteration 9
# ...

# %%
print("Totally iteations: ", iters2)
print("The local minimum occurs at", cur_x2)
# Out:
# Totally iteations:  10000
# The local minimum occurs at 2.99999196531153

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history2, x_history2, 'o-', ms=3, lw=1.5, color='black')
plt.title('lr=0.0001')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()

# %% [markdown]
# ### lr = 0.1時收斂比lr = 0.001時更加快速
#
# ### lr = 0.0001時在限定的跌代次數內無法收斂
